# %%
import sys

# %%
sys.version
# Out:
# '3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]'

# %%
import numpy

# %%
numpy.__version__
# Out:
# '1.16.5'

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.1.1'

# %%
import pandas

# %%
pandas.__version__
# Out:
# '0.25.1'

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.21.3'
